# %% [markdown]
# # Step 1. Defining Exposures
#
# Exposure describes the set of assets, people, livelihoods, infrastructures, etc. within an area of interest in terms of their geographic location, their value etc.; in brief - everything potentially exposed to hazards.
#
# Using LitPop Exposures:
# https://climada-python.readthedocs.io/en/stable/tutorial/climada_entity_LitPop.html

# %%
# %matplotlib inline
import numpy as np
from climada.climadaBR import *

climadabr = ClimadaBR()

# For this cell to work we need the gpw-v4-population-count-rev11_2020_30_sec_tif foulder.
# You can find out more about it in the LitPop tutorial. After downloading, you can copy it to the system
#  directory or to your preferred repository.
# If you are using gpw-v4-population-count-rev11_2020_30_sec_tif (NASA) in the climada system directory 
# "SYSTEM_DIR" you don't need any aditional arguments, but if it is in another directory you can include 
# the path by adding the argument: Path("/path/to/your/directory/").
# For example: climadabr.DefineExposures(['BRA'], 300, 'income_group', Path("/content/Climada_Workspace/climada_python/climada/data/"))
climadabr.DefineExposures(['BRA'], 300, 'income_group')
# Out:
# /home/lucas_of/anaconda3/envs/climada_env3/lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.1. Please consider upgrading.
#   warnings.warn(
# 2024-07-26 04:13:04,314 - climada.entity.exposures.litpop.litpop - INFO -
#  LitPop: Init Exposure for country: BRA (76)...
#
# 2024-07-26 04:13:11,783 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:11,784 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:11,839 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:11,840 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:11,932 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:11,933 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:11,959 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:11,960 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:11,987 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:11,988 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,021 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,021 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,051 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,052 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,087 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,088 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,107 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,108 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,144 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,145 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,173 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,174 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,196 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,197 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,221 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,222 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,246 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,247 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,266 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,268 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,301 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,302 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,327 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,328 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,349 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,350 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,379 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,380 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,398 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,399 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,427 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,428 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,463 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,464 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,488 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,489 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,509 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,510 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,533 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,534 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,558 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,559 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,582 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,583 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,603 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,604 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,628 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,629 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,657 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,658 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,682 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,682 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,690 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-07-26 04:13:12,691 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,692 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,698 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-07-26 04:13:12,699 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,699 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,730 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,730 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,758 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,759 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,782 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,783 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,802 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,803 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,823 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,823 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,845 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,846 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,866 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,867 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,876 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-07-26 04:13:12,877 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,877 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:12,902 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-07-26 04:13:12,903 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-07-26 04:13:28,163 - climada.util.finance - INFO - GDP BRA 2018: 1.917e+12.
# 2024-07-26 04:13:28,192 - climada.util.finance - INFO - Income group BRA 2018: 3.
# 2024-07-26 04:13:28,213 - climada.entity.exposures.base - INFO - Hazard type not set in impf_
# 2024-07-26 04:13:28,214 - climada.entity.exposures.base - INFO - category_id not set.
# 2024-07-26 04:13:28,214 - climada.entity.exposures.base - INFO - cover not set.
# 2024-07-26 04:13:28,214 - climada.entity.exposures.base - INFO - deductible not set.
# 2024-07-26 04:13:28,215 - climada.entity.exposures.base - INFO - centr_ not set.
# 2024-07-26 04:13:28,216 - climada.entity.exposures.base - INFO - Hazard type not set in impf_
# 2024-07-26 04:13:28,217 - climada.entity.exposures.base - INFO - category_id not set.
# 2024-07-26 04:13:28,217 - climada.entity.exposures.base - INFO - cover not set.
# 2024-07-26 04:13:28,218 - climada.entity.exposures.base - INFO - deductible not set.
# 2024-07-26 04:13:28,218 - climada.entity.exposures.base - INFO - centr_ not set.
# 2024-07-26 04:13:28,222 - climada.util.coordinates - INFO - Raster from resolution 0.08333332999999854 to 0.08333332999999854.

# %% [markdown]
# # Step 2. Defining Hazards
#
# A hazard describes climate-related events such as storms, floods, droughts, or heat waves both in terms of probability of occurrence as well as physical intensity.
#
# **IMPORTANT:** In our project, we will extend the hazards to include events generated by climate change, such as the growth of diseases, mosquito-borne vectors, impacts on crops, pollution, effects on the healthcare system, and any other range of events that we can model from news articles extracted from the portals of the country in question.

# %%
climadabr.DefineRandomHazards()

# %% [markdown]
# # Step 3. Computing Impact
#
# The impact is the combined effect of hazard events on a set of exposures mediated by a set of impact functions. By computing the impact for each event (historical and synthetic) and for each exposure value at each geographical location, the Impact provides different risk measures, such as the expected annual impact per exposure, the probable maximum impact for different return periods, and the total average annual impact.
#
# An impact function relates the percentage of damage in the exposure to the hazard intensity, also commonly referred to as a “vulnerability curve” in the modelling community. Every hazard and exposure types are characterized by an impact function.

# %%
climadabr.DefineImpactFuncSet()
climadabr.ComputeImpact()
# Out:
# 2024-07-26 04:15:23,062 - climada.entity.exposures.base - INFO - Exposures matching centroids already found for WS
# 2024-07-26 04:15:23,062 - climada.entity.exposures.base - INFO - Existing centroids will be overwritten for WS
# 2024-07-26 04:15:23,063 - climada.entity.exposures.base - INFO - Matching 101818 exposures with 50 centroids.
# 2024-07-26 04:15:23,065 - climada.util.coordinates - INFO - No exact centroid match found. Reprojecting coordinates to nearest neighbor closer than the threshold = 100
# 2024-07-26 04:15:23,156 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 95946 coordinates.
# 2024-07-26 04:15:23,160 - climada.engine.impact_calc - INFO - Calculating impact for 17616 assets (>0) and 50 events.
# 2024-07-26 04:15:23,170 - climada.util.coordinates - INFO - Setting geometry points.
# 2024-07-26 04:15:23,334 - climada.util.coordinates - INFO - Raster from resolution 0.08333332999999854 to 0.08333332999999854.
# Aggregated average annual impact: 174655703.0 $
